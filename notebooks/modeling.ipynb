# %%
import sys

sys.path.insert(0, 'C:\\Users\\Z478SG\\Desktop\\Ecole\\OpenClassrooms-Projet-7\\')

# %%
from pipelines.data_processing.pipeline import run_data_processing
import pandas as pd

# %%
# df = run_data_processing()
# Out:
# Train samples: 307511, test samples: 48744
# C:\Users\Z478SG\Desktop\Ecole\openclassrooms-projet-7\pipelines\data_processing\feature_engineering.py:34: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['DAYS_EMPLOYED'].replace(365243, np.nan, inplace= True)
# C:\Users\Z478SG\Desktop\Ecole\openclassrooms-projet-7\pipelines\data_processing\feature_engineering.py:110: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# df.to_csv('../data/05_model_input/processed_data.csv', index=False)

# %%
# df = pd.read_csv('../data/03_primary/processed_data.csv')

# %%
# features_df = df[['SK_ID_CURR', 'PAYMENT_RATE', 'EXT_SOURCE_3', 'EXT_SOURCE_2', 'DAYS_BIRTH', 'EXT_SOURCE_1', 'DAYS_EMPLOYED', 'DAYS_EMPLOYED_PERC', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'ANNUITY_INCOME_PERC', 'INSTAL_DBD_MEAN', 'AMT_ANNUITY']]

# %%
df = pd.read_csv('../data/04_feature/features.csv')

# %%
from pipelines.utils.models import kfold_lightgbm
from pipelines.utils.helpers import timer
import pipelines.utils.models as models

# reload kfold_lightgbm library
import importlib
importlib.reload(models)

feat_importance = kfold_lightgbm(df, num_folds= 10, stratified= False)
# Out:
# Starting LightGBM. Train shape: (307507, 797), test shape: (48744, 797)
# C:\Users\Z478SG\Desktop\Ecole\openclassrooms-projet-7\pipelines\utils\models.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df[col] = test_df[col].astype(float)
# C:\Users\Z478SG\Desktop\Ecole\openclassrooms-projet-7\pipelines\utils\models.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df[col] = test_df[col].astype(float)
# ...

# %% [markdown]
# AUC moyen de 0.78 --> Le modèle tombe en moyenne 78% de fois sur la bonne réponse (>0.5 donc mieux qu'aléatoire)
#
# Etapes suivantes :
# - Set 3 repo ou branches git
# - Lancer tracking avec ML flow
# - Selection de features (si besoin combinaisons polynomiales) ==> enregistrer tous les tests avec mlflow
# - Définition du seuil de proba
# - Quand modèle parfait -> mettre sur API, tester en local puis deployer
# - Quand API fonctionne -> mettre dashboard, tester en local puis deployer

# %%
# save feature importance
feat_importance.to_csv('../data/07_model_output/feature_importance.csv', index=False)
